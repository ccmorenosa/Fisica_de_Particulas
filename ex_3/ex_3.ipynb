// %%
#include <iostream>
#include <string>
#include <stdio.h>

// %%
// Open de Root File
  TFile *file = TFile::Open("../ROOT_Files/Data_8TeV.root");

  // Get the Tree from the Root File
  TTree *tree = (TTree*) file->Get("mini");
  tree->Print();

  Bool_t e_trig;
  Bool_t mu_trig;
  Bool_t good_vtx;

  UInt_t lep_n;
  UInt_t jet_n;

  Float_t MET;
  Float_t MET_phi;

  Float_t lep_pt[10];
  Float_t lep_eta[10];
  Float_t lep_phi[10];
  Float_t lep_E[10];

  Int_t lep_type[10];

  Float_t lep_ptcone30[10];
  Float_t lep_etcone20[10];

  Float_t jet_pt[10];
  Float_t jet_eta[10];
  Float_t jet_jvf[10];
  Float_t jet_mv1[10];

  tree->SetBranchAddress("trigE", &e_trig);
  tree->SetBranchAddress("trigM", &mu_trig);
  tree->SetBranchAddress("hasGoodVertex", &good_vtx);
  tree->SetBranchAddress("lep_n", &lep_n);
  tree->SetBranchAddress("jet_n", &jet_n);
  tree->SetBranchAddress("met_et", &MET);
  tree->SetBranchAddress("met_phi", &MET_phi);

  tree->SetBranchAddress("lep_pt", &lep_pt);
  tree->SetBranchAddress("lep_eta", &lep_eta);
  tree->SetBranchAddress("lep_phi", &lep_phi);
  tree->SetBranchAddress("lep_E", &lep_E);
  tree->SetBranchAddress("lep_type", &lep_type);
  tree->SetBranchAddress("lep_ptcone30", &lep_ptcone30);
  tree->SetBranchAddress("lep_etcone20", &lep_etcone20);

  tree->SetBranchAddress("jet_pt", &jet_pt);
  tree->SetBranchAddress("jet_eta", &jet_eta);
  tree->SetBranchAddress("jet_jvf", &jet_jvf);
  tree->SetBranchAddress("jet_MV1", &jet_mv1);

  TCanvas *canvas = new TCanvas("Canvas", "", 800, 600);

  // Histogram for cuts
  TH1F *cutflow = new TH1F("Cutflow","Cutflow; Cut; Events",10,0,10);

  // Histograms for Leptons
  TH1F *hist_lep_pt = new TH1F(
    "Leptons pT", "Leptons pT; pT (GeV); Events",
    50, 0, 1000
  );

  TH1F *hist_lep_pt_cone30 = new TH1F(
    "Track isolation", "Track isolation; lep_ptcone30/lep_pt; Events",
    50, 0, 0.2
  );

  TH1F *hist_lep_et_cone20 = new TH1F(
    "Calorimeter isolation",
    "Calorimeter isolation; lep_etcone30/lep_pt; Events",
    50, 0, 0.2
  );

  TH1F *hist_lep_eta = new TH1F(
    "Leptons eta", "Leptons eta; eta; Events",
    50, -5, 5
  );

  // Histograms for Jets
  TH1F *hist_njets = new TH1F(
    "Number of jets", "n-jets; Jet multiplicity; Events",
    10,0,10
  );

  TH1F *hist_jet_pt = new TH1F(
    "Jets pT", "Jets pT; pT (GeV); Events",
    50, 0, 1000
  );

  TH1F *hist_jet_eta = new TH1F(
    "Jets eta", "Jets eta; eta; Events",
    50, -5, 5
  );

  TH1F *hist_jet_JVF = new TH1F(
    "Jets JVF", "Jets JVF; JVF; Events",
    50, 0, 1
  );

  TH1F *hist_jet_MV1 = new TH1F(
    "Jets MV1", "Jets MV1; MV1; Events",
    50, 0.5, 1
  );

  // Histogram for bJets
  TH1F *hist_nbjets = new TH1F(
    "Number of b-jets", "n-bjets; b-Jet multiplicity; Events",
    50, 0, 6
  );

  // Histogram for MET
  TH1F *hist_MET = new TH1F(
    "MET", "MET; MET (GeV); Events",
    50, 0, 200
  );

  // Histogram for mTW
  TH1F *hist_mTW = new TH1F(
    "mTW", "mTW; mTW (GeV); Events",
    50, 0, 200
  );
// Out:
// ******************************************************************************
// *Tree    :mini      : 4-vectors + variables required for scaling factors     *
// *Entries : 14945674 : Total =      3737586466 bytes  File  Size = 1366006484 *
// *        :          : Tree compression factor =   2.74                       *
// ******************************************************************************
// *Br    0 :runNumber : runNumber/I                                            *
// *Entries : 14945674 : Total  Size=   59789737 bytes  File Size  =     297928 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression= 200.68     *
// *............................................................................*
// *Br    1 :eventNumber : eventNumber/I                                        *
// *Entries : 14945674 : Total  Size=   59789885 bytes  File Size  =   44412272 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression=   1.35     *
// *............................................................................*
// *Br    2 :channelNumber : channelNumber/I                                    *
// *Entries : 14945674 : Total  Size=   59790033 bytes  File Size  =     298208 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression= 200.49     *
// *............................................................................*
// *Br    3 :mcWeight  : mcWeight/F                                             *
// *Entries : 14945674 : Total  Size=   59789663 bytes  File Size  =     268231 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression= 222.90     *
// *............................................................................*
// *Br    4 :pvxp_n    : pvxp_n/I                                               *
// *Entries : 14945674 : Total  Size=   59789515 bytes  File Size  =   13103705 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression=   4.56     *
// *............................................................................*
// *Br    5 :vxp_z     : vxp_z/F                                                *
// *Entries : 14945674 : Total  Size=   59789441 bytes  File Size  =   55540897 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression=   1.08     *
// *............................................................................*
// *Br    6 :scaleFactor_PILEUP : scaleFactor_PILEUP/F                          *
// *Entries : 14945674 : Total  Size=   59790403 bytes  File Size  =     268931 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression= 222.32     *
// *............................................................................*
// *Br    7 :scaleFactor_ELE : scaleFactor_ELE/F                                *
// *Entries : 14945674 : Total  Size=   59790181 bytes  File Size  =     268721 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression= 222.49     *
// *............................................................................*
// *Br    8 :scaleFactor_MUON : scaleFactor_MUON/F                              *
// *Entries : 14945674 : Total  Size=   59790255 bytes  File Size  =     268791 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression= 222.43     *
// *............................................................................*
// *Br    9 :scaleFactor_BTAG : scaleFactor_BTAG/F                              *
// *Entries : 14945674 : Total  Size=   59790255 bytes  File Size  =     268791 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression= 222.43     *
// *............................................................................*
// *Br   10 :scaleFactor_TRIGGER : scaleFactor_TRIGGER/F                        *
// *Entries : 14945674 : Total  Size=   59790477 bytes  File Size  =     269001 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression= 222.26     *
// *............................................................................*
// *Br   11 :scaleFactor_JVFSF : scaleFactor_JVFSF/F                            *
// *Entries : 14945674 : Total  Size=   59790329 bytes  File Size  =     268861 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression= 222.38     *
// *............................................................................*
// *Br   12 :scaleFactor_ZVERTEX : scaleFactor_ZVERTEX/F                        *
// *Entries : 14945674 : Total  Size=   59790477 bytes  File Size  =     269001 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression= 222.26     *
// *............................................................................*
// *Br   13 :trigE     : trigE/O                                                *
// *Entries : 14945674 : Total  Size=   14958761 bytes  File Size  =      79720 *
// *Baskets :      139 : Basket Size=     159744 bytes  Compression= 187.60     *
// *............................................................................*
// *Br   14 :trigM     : trigM/O                                                *
// *Entries : 14945674 : Total  Size=   14958761 bytes  File Size  =     104652 *
// *Baskets :      139 : Basket Size=     159744 bytes  Compression= 142.91     *
// *............................................................................*
// *Br   15 :passGRL   : passGRL/O                                              *
// *Entries : 14945674 : Total  Size=   14959047 bytes  File Size  =      80772 *
// *Baskets :      139 : Basket Size=     159744 bytes  Compression= 185.16     *
// *............................................................................*
// *Br   16 :hasGoodVertex : hasGoodVertex/O                                    *
// *Entries : 14945674 : Total  Size=   14959905 bytes  File Size  =     829254 *
// *Baskets :      139 : Basket Size=     159744 bytes  Compression=  18.04     *
// *............................................................................*
// *Br   17 :lep_n     : lep_n/i                                                *
// *Entries : 14945674 : Total  Size=   59789441 bytes  File Size  =    2971296 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression=  20.12     *
// *............................................................................*
// *Br   18 :lep_truthMatched : lep_truthMatched[lep_n]/O                       *
// *Entries : 14945674 : Total  Size=   75857338 bytes  File Size  =   20999814 *
// *Baskets :      139 : Basket Size=    1224192 bytes  Compression=   3.61     *
// *............................................................................*
// *Br   19 :lep_trigMatched : lep_trigMatched[lep_n]/s                         *
// *Entries : 14945674 : Total  Size=   91915976 bytes  File Size  =   24049899 *
// *Baskets :      139 : Basket Size=    1224192 bytes  Compression=   3.82     *
// *............................................................................*
// *Br   20 :lep_pt    : lep_pt[lep_n]/F                                        *
// *Entries : 14945674 : Total  Size=  124039220 bytes  File Size  =   74690269 *
// *Baskets :      208 : Basket Size=    1224192 bytes  Compression=   1.66     *
// *............................................................................*
// *Br   21 :lep_eta   : lep_eta[lep_n]/F                                       *
// *Entries : 14945674 : Total  Size=  124039432 bytes  File Size  =   77563362 *
// *Baskets :      208 : Basket Size=    1224192 bytes  Compression=   1.60     *
// *............................................................................*
// *Br   22 :lep_phi   : lep_phi[lep_n]/F                                       *
// *Entries : 14945674 : Total  Size=  124039432 bytes  File Size  =   77598012 *
// *Baskets :      208 : Basket Size=    1224192 bytes  Compression=   1.60     *
// *............................................................................*
// *Br   23 :lep_E     : lep_E[lep_n]/F                                         *
// *Entries : 14945674 : Total  Size=  124039008 bytes  File Size  =   75496519 *
// *Baskets :      208 : Basket Size=    1224192 bytes  Compression=   1.64     *
// *............................................................................*
// *Br   24 :lep_z0    : lep_z0[lep_n]/F                                        *
// *Entries : 14945674 : Total  Size=  124039220 bytes  File Size  =   78351134 *
// *Baskets :      208 : Basket Size=    1224192 bytes  Compression=   1.58     *
// *............................................................................*
// *Br   25 :lep_charge : lep_charge[lep_n]/F                                   *
// *Entries : 14945674 : Total  Size=  124040068 bytes  File Size  =   25355214 *
// *Baskets :      208 : Basket Size=    1224192 bytes  Compression=   4.89     *
// *............................................................................*
// *Br   26 :lep_type  : lep_type[lep_n]/i                                      *
// *Entries : 14945674 : Total  Size=  124039637 bytes  File Size  =   18822849 *
// *Baskets :      208 : Basket Size=    1224192 bytes  Compression=   6.59     *
// *............................................................................*
// *Br   27 :lep_flag  : lep_flag[lep_n]/i                                      *
// *Entries : 14945674 : Total  Size=  124039637 bytes  File Size  =   31625869 *
// *Baskets :      208 : Basket Size=    1224192 bytes  Compression=   3.92     *
// *............................................................................*
// *Br   28 :lep_ptcone30 : lep_ptcone30[lep_n]/F                               *
// *Entries : 14945674 : Total  Size=  124040492 bytes  File Size  =   45473662 *
// *Baskets :      208 : Basket Size=    1224192 bytes  Compression=   2.73     *
// *............................................................................*
// *Br   29 :lep_etcone20 : lep_etcone20[lep_n]/F                               *
// *Entries : 14945674 : Total  Size=  124040492 bytes  File Size  =   75793466 *
// *Baskets :      208 : Basket Size=    1224192 bytes  Compression=   1.64     *
// *............................................................................*
// *Br   30 :lep_trackd0pvunbiased : lep_trackd0pvunbiased[lep_n]/F             *
// *Entries : 14945674 : Total  Size=  124042400 bytes  File Size  =   78337113 *
// *Baskets :      208 : Basket Size=    1224192 bytes  Compression=   1.58     *
// *............................................................................*
// *Br   31 :lep_tracksigd0pvunbiased : lep_tracksigd0pvunbiased[lep_n]/F       *
// *Entries : 14945674 : Total  Size=  124043036 bytes  File Size  =   74120311 *
// *Baskets :      208 : Basket Size=    1224192 bytes  Compression=   1.67     *
// *............................................................................*
// *Br   32 :met_et    : met_et/F                                               *
// *Entries : 14945674 : Total  Size=   59789515 bytes  File Size  =   53578213 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression=   1.12     *
// *............................................................................*
// *Br   33 :met_phi   : met_phi/F                                              *
// *Entries : 14945674 : Total  Size=   59789589 bytes  File Size  =   55415952 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   34 :jet_n     : jet_n/i                                                *
// *Entries : 14945674 : Total  Size=   59789441 bytes  File Size  =    7425059 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression=   8.05     *
// *............................................................................*
// *Br   35 :alljet_n  : alljet_n/i                                             *
// *Entries : 14945674 : Total  Size=   59789663 bytes  File Size  =    7943976 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression=   7.53     *
// *............................................................................*
// *Br   36 :jet_pt    : jet_pt[alljet_n]/F                                     *
// *Entries : 14945674 : Total  Size=   94527479 bytes  File Size  =   43503461 *
// *Baskets :      139 : Basket Size=    1224192 bytes  Compression=   2.17     *
// *............................................................................*
// *Br   37 :jet_eta   : jet_eta[alljet_n]/F                                    *
// *Entries : 14945674 : Total  Size=   94527622 bytes  File Size  =   44933234 *
// *Baskets :      139 : Basket Size=    1224192 bytes  Compression=   2.10     *
// *............................................................................*
// *Br   38 :jet_phi   : jet_phi[alljet_n]/F                                    *
// *Entries : 14945674 : Total  Size=   94527622 bytes  File Size  =   44929226 *
// *Baskets :      139 : Basket Size=    1224192 bytes  Compression=   2.10     *
// *............................................................................*
// *Br   39 :jet_E     : jet_E[alljet_n]/F                                      *
// *Entries : 14945674 : Total  Size=   94527336 bytes  File Size  =   43801321 *
// *Baskets :      139 : Basket Size=    1224192 bytes  Compression=   2.16     *
// *............................................................................*
// *Br   40 :jet_m     : jet_m[alljet_n]/F                                      *
// *Entries : 14945674 : Total  Size=   94527336 bytes  File Size  =   43460012 *
// *Baskets :      139 : Basket Size=    1224192 bytes  Compression=   2.17     *
// *............................................................................*
// *Br   41 :jet_jvf   : jet_jvf[alljet_n]/F                                    *
// *Entries : 14945674 : Total  Size=   94527622 bytes  File Size  =   39392706 *
// *Baskets :      139 : Basket Size=    1224192 bytes  Compression=   2.40     *
// *............................................................................*
// *Br   42 :jet_trueflav : jet_trueflav[alljet_n]/I                            *
// *Entries : 14945674 : Total  Size=   94528330 bytes  File Size  =   12915685 *
// *Baskets :      139 : Basket Size=    1224192 bytes  Compression=   7.32     *
// *............................................................................*
// *Br   43 :jet_truthMatched : jet_truthMatched[alljet_n]/I                    *
// *Entries : 14945674 : Total  Size=   94528902 bytes  File Size  =   12893729 *
// *Baskets :      139 : Basket Size=    1224192 bytes  Compression=   7.33     *
// *............................................................................*
// *Br   44 :jet_SV0   : jet_SV0[alljet_n]/F                                    *
// *Entries : 14945674 : Total  Size=   94527622 bytes  File Size  =   16306468 *
// *Baskets :      139 : Basket Size=    1224192 bytes  Compression=   5.80     *
// *............................................................................*
// *Br   45 :jet_MV1   : jet_MV1[alljet_n]/F                                    *
// *Entries : 14945674 : Total  Size=   94527622 bytes  File Size  =   41303912 *
// *Baskets :      139 : Basket Size=    1224192 bytes  Compression=   2.29     *
// *............................................................................*

// %%
int nentries, nbytes, i;
  nentries = (Int_t)tree->GetEntries();

  int cut1 = 0;
  int cut2 = 0;
  int cut3 = 0;
  int cut4 = 0;
  int cut5 = 0;
  int cut6 = 0;
  int cut7 = 0;
  int cut8 = 0;

  for (i = 0; i < nentries; i++) {
    nbytes = tree->GetEntry(i);

    //First cut: Good vertex
    if(!good_vtx) continue;
    cut1++;
    cutflow->Fill(1);

    //Second cut: Trigger
    if(!e_trig && !mu_trig) continue;
    cut2++;
    cutflow->Fill(2);

    // Preselection of good leptons
    int n_mu = 0;
    int n_el = 0;
    int n_lep = 0;
    int g_lep = 0;

    //Loop over leptons
    for (unsigned int j=0; j < lep_n; j++) {
      hist_lep_pt->Fill(lep_pt[j] / 1000);
      hist_lep_pt_cone30->Fill(lep_ptcone30[j] / lep_pt[j]);
      hist_lep_et_cone20->Fill(lep_etcone20[j] / lep_pt[j]);
      hist_lep_eta->Fill(lep_eta[j]);

      if( lep_pt[j] < 25000.0) continue;

      if( lep_ptcone30[j]/lep_pt[j] > 0.15 ) continue;

      if( lep_etcone20[j]/lep_pt[j] > 0.15 ) continue;

      if(lep_type[j] == 13 && TMath::Abs(lep_eta[j]) < 2.5){
        n_mu++;
        g_lep = j;
      }

      if (lep_type[j]==11 && TMath::Abs(lep_eta[j]) < 2.47){
        if (TMath::Abs(lep_eta[j]) < 1.37 || TMath::Abs(lep_eta[j]) > 1.52) {
          n_el++;
          g_lep = j;
        }
      }

    }
    n_lep = n_el + n_mu;

    //Select events with only 1 good lepton and fill the cutflow histogram
    if (n_lep != 1) continue;
    cutflow->Fill(3);
    cut3++;


    int n_jets = 0;
    int n_bjets = 0;

    //Number of jets distribution
    hist_njets->Fill(jet_n);

    //Fourth cut: At least 4 jets
    if (jet_n < 4) continue;
    cutflow->Fill(4);
    cut4++;

    for (unsigned int j=0; j < jet_n; j++){
      hist_jet_pt->Fill(jet_pt[j] / 1000);
      hist_jet_eta->Fill(jet_eta[j]);
      hist_jet_JVF->Fill(jet_jvf[j]);
      hist_jet_MV1->Fill(jet_mv1[j]);
      // To complete: apply jet cuts to find the good jets
      if (jet_pt[j] < 25000.) continue;

      //Eta cut
      if (jet_eta[j] > 2.5) continue;
      // JVF cleaning
      if (jet_pt[j] < 50000. && TMath::Abs(jet_eta[j]) < 2.4) {
        if (jet_jvf[j] < 0.5) continue;
      }

      n_jets ++;

      // cut on 0.7892 MV1 and count the number of b-jets
      if (jet_mv1[j] < 0.7892) continue;

      n_bjets ++;
    }


    //Fifth cut: At least 4 good jets
    if (n_jets < 4) continue;
    cutflow->Fill(5);
    cut5++;

    //Sixth cut: at least one b-jet
    hist_nbjets->Fill(n_bjets);
    if (n_bjets < 2) continue;
    cutflow->Fill(6);
    cut6++;

    //Seventh cut: MET > 30 GeV
    hist_MET->Fill(MET / 1000);
    if (MET < 30000.) continue;
    cutflow->Fill(7);
    cut7++;

    // TLorentzVector definitions
    TLorentzVector Lepton  = TLorentzVector();
    TLorentzVector  MeT  = TLorentzVector();

    //To complete: Lorentz vectors for the lepton and MET. Use SetPtEtaPhiE().
    Lepton.SetPtEtaPhiE(
      lep_pt[g_lep],
      lep_eta[g_lep],
      lep_phi[g_lep],
      lep_E[g_lep]
    );

    MeT.SetPtEtaPhiE(
      MET,
      0,
      MET_phi,
      MET
    );

    //Calculation of the mTW using TLorentz vectors
    float mTW = sqrt(2*Lepton.Pt()*MeT.Et()*(1-cos(Lepton.DeltaPhi(MeT))));

    //Eight cut: mTW > 30 GeV
    hist_mTW->Fill(mTW / 1000);
    if (mTW < 30000.) continue;
    cutflow->Fill(8);
    cut8++;
  }

  std::cout << "Done!" << std::endl;
  std::cout << "All events:" << nentries << std::endl;
  std::cout << "Cut1:" << cut1 << std::endl;
  std::cout << "Cut2:" << cut2 << std::endl;
  std::cout << "Cut3:" << cut3 << std::endl;
  std::cout << "Cut4:" << cut4 << std::endl;
  std::cout << "Cut5:" << cut5 << std::endl;
  std::cout << "Cut6:" << cut6 << std::endl;
  std::cout << "Cut7:" << cut7 << std::endl;
  std::cout << "Cut8:" << cut8 << std::endl;
// Out:
// Done!
// All events:14945674
// Cut1:14656440
// Cut2:14656440
// Cut3:11533698
// Cut4:61833
// Cut5:61516
// Cut6:10804
// Cut7:8557
// Cut8:7180

// %%
std::cout << "Saving Histograms" << '\n';
  std::cout << '\n';

  std::cout << '\n';
  std::cout << "Histogram for Cuts" << '\n';
  std::cout << '\n';

  canvas->SetLogy();
  cutflow->SetFillColor(kCyan);
  cutflow->Draw("");
  canvas->Print("cutflow.svg");
  canvas->Clear();

  std::cout << '\n';
  std::cout << "Histogram for Leptons" << '\n';
  std::cout << '\n';

  hist_lep_pt->SetFillColor(kCyan);
  hist_lep_pt->Draw();
  canvas->Print("hist_lep_pt.svg");
  canvas->Clear();

  hist_lep_pt_cone30->SetFillColor(kCyan);
  hist_lep_pt_cone30->Draw();
  canvas->Print("hist_lep_pt_cone30.svg");
  canvas->Clear();

  hist_lep_et_cone20->SetFillColor(kCyan);
  hist_lep_et_cone20->Draw();
  canvas->Print("hist_lep_et_cone20.svg");
  canvas->Clear();

  hist_lep_eta->SetFillColor(kCyan);
  hist_lep_eta->Draw();
  canvas->Print("hist_lep_eta.svg");
  canvas->Clear();

  std::cout << '\n';
  std::cout << "Histogram for Jets" << '\n';
  std::cout << '\n';

  hist_njets->SetFillColor(kCyan);
  hist_njets->Draw();
  canvas->Print("hist_njets.svg");
  canvas->Clear();

  hist_jet_pt->SetFillColor(kCyan);
  hist_jet_pt->Draw();
  canvas->Print("hist_jet_pt.svg");
  canvas->Clear();

  hist_jet_eta->SetFillColor(kCyan);
  hist_jet_eta->Draw();
  canvas->Print("hist_jet_eta.svg");
  canvas->Clear();

  hist_jet_JVF->SetFillColor(kCyan);
  hist_jet_JVF->Draw();
  canvas->Print("hist_jet_JVF.svg");
  canvas->Clear();

  hist_jet_MV1->SetFillColor(kCyan);
  hist_jet_MV1->Draw();
  canvas->Print("hist_jet_MV1.svg");
  canvas->Clear();

  std::cout << '\n';
  std::cout << "Histogram for b-Jets" << '\n';
  std::cout << '\n';

  hist_nbjets->SetFillColor(kCyan);
  hist_nbjets->Draw();
  canvas->Print("hist_nbjets.svg");
  canvas->Clear();
  canvas->SetLogy(false);

  std::cout << '\n';
  std::cout << "Histogram for MET" << '\n';
  std::cout << '\n';

  hist_MET->SetFillColor(kCyan);
  hist_MET->Draw();
  canvas->Print("hist_MET.svg");
  canvas->Clear();

  std::cout << '\n';
  std::cout << "Histogram for mTW" << '\n';
  std::cout << '\n';

  hist_mTW->SetFillColor(kCyan);
  hist_mTW->Draw();
  canvas->Print("hist_mTW.svg");
  canvas->Clear();

  std::cout << '\n';
  std::cout << '\n';
  std::cout << "Done" << '\n';
// Out:
// Saving Histograms
//
//
// Histogram for Cuts
// Thread 9 (Thread 0x7fcf5edfc640 (LWP 46366)):
// #0  0x00007fcf7e374b7b in select () from /usr/lib/libc.so.6
// #1  0x00007fcf7e66ddae in ?? () from /usr/lib/libpython3.8.so.1.0
// #2  0x00007fcf7e5746ef in ?? () from /usr/lib/libpython3.8.so.1.0
// #3  0x00007fcf7e569025 in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #4  0x00007fcf7e575138 in _PyFunction_Vectorcall () from /usr/lib/libpython3.8.so.1.0
// #5  0x00007fcf7e564ac1 in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #6  0x00007fcf7e575138 in _PyFunction_Vectorcall () from /usr/lib/libpython3.8.so.1.0
// #7  0x00007fcf7e564ac1 in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #8  0x00007fcf7e575138 in _PyFunction_Vectorcall () from /usr/lib/libpython3.8.so.1.0
// #9  0x00007fcf7e584b3c in ?? () from /usr/lib/libpython3.8.so.1.0
// #10 0x00007fcf7e5882c2 in PyObject_Call () from /usr/lib/libpython3.8.so.1.0
// #11 0x00007fcf7e64dc91 in ?? () from /usr/lib/libpython3.8.so.1.0
// #12 0x00007fcf7e6327d4 in ?? () from /usr/lib/libpython3.8.so.1.0
// #13 0x00007fcf7e2643e9 in start_thread () from /usr/lib/libpthread.so.0
// #14 0x00007fcf7e37d293 in clone () from /usr/lib/libc.so.6
//
// Thread 8 (Thread 0x7fcf5f7fe640 (LWP 46365)):
// #0  0x00007fcf7e349eef in wait4 () from /usr/lib/libc.so.6
// #1  0x00007fcf7e2c748f in do_system () from /usr/lib/libc.so.6
// #2  0x00007fcf7bb33df2 in TUnixSystem::StackTrace() () from /usr/lib/root/libCore.so
// #3  0x00007fcf78062ff8 in ?? () from /usr/lib/root/libCling.so
// #4  0x00007fcf78062987 in cling_runtime_internal_throwIfInvalidPointer () from /usr/lib/root/libCling.so
// #5  0x00007fcf6c05e0fb in ?? ()
// #6  0x0000000000000000 in ?? ()
//
// Thread 7 (Thread 0x7fcf5ffff640 (LWP 46105)):
// #0  0x00007fcf7e37d5de in epoll_wait () from /usr/lib/libc.so.6
// #1  0x00007fcf6eed691a in ?? () from /usr/lib/libzmq.so.5
// #2  0x00007fcf6ef1809f in ?? () from /usr/lib/libzmq.so.5
// #3  0x00007fcf7e2643e9 in start_thread () from /usr/lib/libpthread.so.0
// #4  0x00007fcf7e37d293 in clone () from /usr/lib/libc.so.6
//
// Thread 6 (Thread 0x7fcf6c9b6640 (LWP 46104)):
// #0  0x00007fcf7e37d5de in epoll_wait () from /usr/lib/libc.so.6
// #1  0x00007fcf6eed691a in ?? () from /usr/lib/libzmq.so.5
// #2  0x00007fcf6ef1809f in ?? () from /usr/lib/libzmq.so.5
// #3  0x00007fcf7e2643e9 in start_thread () from /usr/lib/libpthread.so.0
// #4  0x00007fcf7e37d293 in clone () from /usr/lib/libc.so.6
//
// Thread 5 (Thread 0x7fcf6d1b7640 (LWP 46103)):
// #0  0x00007fcf7e37246f in poll () from /usr/lib/libc.so.6
// #1  0x00007fcf6ef26bb9 in zmq_poll () from /usr/lib/libzmq.so.5
// #2  0x00007fcf6eef5699 in ?? () from /usr/lib/libzmq.so.5
// #3  0x00007fcf6ed81445 in ?? () from /usr/lib/python3.8/site-packages/zmq/backend/cython/_device.cpython-38-x86_64-linux-gnu.so
// #4  0x00007fcf6ed80c40 in ?? () from /usr/lib/python3.8/site-packages/zmq/backend/cython/_device.cpython-38-x86_64-linux-gnu.so
// #5  0x00007fcf7e56db84 in _PyObject_MakeTpCall () from /usr/lib/libpython3.8.so.1.0
// #6  0x00007fcf7e569458 in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #7  0x00007fcf7e575138 in _PyFunction_Vectorcall () from /usr/lib/libpython3.8.so.1.0
// #8  0x00007fcf7e564ac1 in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #9  0x00007fcf7e575138 in _PyFunction_Vectorcall () from /usr/lib/libpython3.8.so.1.0
// #10 0x00007fcf7e564ac1 in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #11 0x00007fcf7e575138 in _PyFunction_Vectorcall () from /usr/lib/libpython3.8.so.1.0
// #12 0x00007fcf7e584b3c in ?? () from /usr/lib/libpython3.8.so.1.0
// #13 0x00007fcf7e5882c2 in PyObject_Call () from /usr/lib/libpython3.8.so.1.0
// #14 0x00007fcf7e64dc91 in ?? () from /usr/lib/libpython3.8.so.1.0
// #15 0x00007fcf7e6327d4 in ?? () from /usr/lib/libpython3.8.so.1.0
// #16 0x00007fcf7e2643e9 in start_thread () from /usr/lib/libpthread.so.0
// #17 0x00007fcf7e37d293 in clone () from /usr/lib/libc.so.6
//
// Thread 4 (Thread 0x7fcf6d9b8640 (LWP 46102)):
// #0  0x00007fcf7e37d5de in epoll_wait () from /usr/lib/libc.so.6
// #1  0x00007fcf7d82a6d7 in ?? () from /usr/lib/python3.8/lib-dynload/select.cpython-38-x86_64-linux-gnu.so
// #2  0x00007fcf7e59797e in ?? () from /usr/lib/libpython3.8.so.1.0
// #3  0x00007fcf7e564ac1 in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #4  0x00007fcf7e563044 in _PyEval_EvalCodeWithName () from /usr/lib/libpython3.8.so.1.0
// #5  0x00007fcf7e5751cd in _PyFunction_Vectorcall () from /usr/lib/libpython3.8.so.1.0
// #6  0x00007fcf7e564ac1 in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #7  0x00007fcf7e575138 in _PyFunction_Vectorcall () from /usr/lib/libpython3.8.so.1.0
// #8  0x00007fcf7e564ac1 in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #9  0x00007fcf7e575138 in _PyFunction_Vectorcall () from /usr/lib/libpython3.8.so.1.0
// #10 0x00007fcf7e564ac1 in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #11 0x00007fcf7e575138 in _PyFunction_Vectorcall () from /usr/lib/libpython3.8.so.1.0
// #12 0x00007fcf7e564ac1 in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #13 0x00007fcf7e575138 in _PyFunction_Vectorcall () from /usr/lib/libpython3.8.so.1.0
// #14 0x00007fcf7e584b3c in ?? () from /usr/lib/libpython3.8.so.1.0
// #15 0x00007fcf7e5882c2 in PyObject_Call () from /usr/lib/libpython3.8.so.1.0
// #16 0x00007fcf7e566838 in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #17 0x00007fcf7e575138 in _PyFunction_Vectorcall () from /usr/lib/libpython3.8.so.1.0
// #18 0x00007fcf7e564ac1 in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #19 0x00007fcf7e575138 in _PyFunction_Vectorcall () from /usr/lib/libpython3.8.so.1.0
// #20 0x00007fcf7e564ac1 in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #21 0x00007fcf7e575138 in _PyFunction_Vectorcall () from /usr/lib/libpython3.8.so.1.0
// #22 0x00007fcf7e584b3c in ?? () from /usr/lib/libpython3.8.so.1.0
// #23 0x00007fcf7e5882c2 in PyObject_Call () from /usr/lib/libpython3.8.so.1.0
// #24 0x00007fcf7e64dc91 in ?? () from /usr/lib/libpython3.8.so.1.0
// #25 0x00007fcf7e6327d4 in ?? () from /usr/lib/libpython3.8.so.1.0
// #26 0x00007fcf7e2643e9 in start_thread () from /usr/lib/libpthread.so.0
// #27 0x00007fcf7e37d293 in clone () from /usr/lib/libc.so.6
//
// Thread 3 (Thread 0x7fcf6e1b9640 (LWP 46101)):
// #0  0x00007fcf7e37d5de in epoll_wait () from /usr/lib/libc.so.6
// #1  0x00007fcf6eed691a in ?? () from /usr/lib/libzmq.so.5
// #2  0x00007fcf6ef1809f in ?? () from /usr/lib/libzmq.so.5
// #3  0x00007fcf7e2643e9 in start_thread () from /usr/lib/libpthread.so.0
// #4  0x00007fcf7e37d293 in clone () from /usr/lib/libc.so.6
//
// Thread 2 (Thread 0x7fcf6e9ba640 (LWP 46100)):
// #0  0x00007fcf7e37d5de in epoll_wait () from /usr/lib/libc.so.6
// #1  0x00007fcf6eed691a in ?? () from /usr/lib/libzmq.so.5
// #2  0x00007fcf6ef1809f in ?? () from /usr/lib/libzmq.so.5
// #3  0x00007fcf7e2643e9 in start_thread () from /usr/lib/libpthread.so.0
// #4  0x00007fcf7e37d293 in clone () from /usr/lib/libc.so.6
//
// Thread 1 (Thread 0x7fcf7e105740 (LWP 46063)):
// #0  0x00007fcf7e26a9c8 in pthread_cond_timedwait
//
// GLIBC_2.3.2 () from /usr/lib/libpthread.so.0
// #1  0x00007fcf7e57c516 in PyEval_RestoreThread () from /usr/lib/libpython3.8.so.1.0
// #2  0x00007fcf7e66ddb8 in ?? () from /usr/lib/libpython3.8.so.1.0
// #3  0x00007fcf7e5746ef in ?? () from /usr/lib/libpython3.8.so.1.0
// #4  0x00007fcf7e5646fd in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #5  0x00007fcf7e563044 in _PyEval_EvalCodeWithName () from /usr/lib/libpython3.8.so.1.0
// #6  0x00007fcf7e5751cd in _PyFunction_Vectorcall () from /usr/lib/libpython3.8.so.1.0
// #7  0x00007fcf7e5646fd in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #8  0x00007fcf7e563044 in _PyEval_EvalCodeWithName () from /usr/lib/libpython3.8.so.1.0
// #9  0x00007fcf7e5751cd in _PyFunction_Vectorcall () from /usr/lib/libpython3.8.so.1.0
// #10 0x00007fcf7e564ac1 in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #11 0x00007fcf7e563044 in _PyEval_EvalCodeWithName () from /usr/lib/libpython3.8.so.1.0
// #12 0x00007fcf7e5751cd in _PyFunction_Vectorcall () from /usr/lib/libpython3.8.so.1.0
// #13 0x00007fcf7e564ac1 in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #14 0x00007fcf7e5a2c5a in ?? () from /usr/lib/libpython3.8.so.1.0
// #15 0x00007fcf7e5f53c3 in ?? () from /usr/lib/libpython3.8.so.1.0
// #16 0x00007fcf7e5759d8 in ?? () from /usr/lib/libpython3.8.so.1.0
// #17 0x00007fcf7e5646fd in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #18 0x00007fcf7e56353a in _PyEval_EvalCodeWithName () from /usr/lib/libpython3.8.so.1.0
// #19 0x00007fcf7e584952 in ?? () from /usr/lib/libpython3.8.so.1.0
// #20 0x00007fcf7e5646fd in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #21 0x00007fcf7e5a2c5a in ?? () from /usr/lib/libpython3.8.so.1.0
// #22 0x00007fcf7e5f53c3 in ?? () from /usr/lib/libpython3.8.so.1.0
// #23 0x00007fcf7e5759d8 in ?? () from /usr/lib/libpython3.8.so.1.0
// #24 0x00007fcf7e5646fd in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #25 0x00007fcf7e56353a in _PyEval_EvalCodeWithName () from /usr/lib/libpython3.8.so.1.0
// #26 0x00007fcf7e5751cd in _PyFunction_Vectorcall () from /usr/lib/libpython3.8.so.1.0
// #27 0x00007fcf7e584b3c in ?? () from /usr/lib/libpython3.8.so.1.0
// #28 0x00007fcf7e5882c2 in PyObject_Call () from /usr/lib/libpython3.8.so.1.0
// #29 0x00007fcf7e566838 in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #30 0x00007fcf7e5a2c5a in ?? () from /usr/lib/libpython3.8.so.1.0
// #31 0x00007fcf7e580c03 in ?? () from /usr/lib/libpython3.8.so.1.0
// #32 0x00007fcf7e564ac1 in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #33 0x00007fcf7e575138 in _PyFunction_Vectorcall () from /usr/lib/libpython3.8.so.1.0
// #34 0x00007fcf7e564ac1 in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #35 0x00007fcf7e56cf5e in _PyObject_FastCallDict () from /usr/lib/libpython3.8.so.1.0
// #36 0x00007fcf7e57fb77 in ?? () from /usr/lib/libpython3.8.so.1.0
// #37 0x00007fcf7e56dc20 in _PyObject_MakeTpCall () from /usr/lib/libpython3.8.so.1.0
// #38 0x00007fcf7e568f54 in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #39 0x00007fcf7e56353a in _PyEval_EvalCodeWithName () from /usr/lib/libpython3.8.so.1.0
// #40 0x00007fcf7e5751cd in _PyFunction_Vectorcall () from /usr/lib/libpython3.8.so.1.0
// #41 0x00007fcf7e564ac1 in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #42 0x00007fcf7e5a2c5a in ?? () from /usr/lib/libpython3.8.so.1.0
// #43 0x00007fcf7e580c03 in ?? () from /usr/lib/libpython3.8.so.1.0
// #44 0x00007fcf7e564ac1 in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #45 0x00007fcf7e575138 in _PyFunction_Vectorcall () from /usr/lib/libpython3.8.so.1.0
// #46 0x00007fcf7e564ac1 in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #47 0x00007fcf7e56353a in _PyEval_EvalCodeWithName () from /usr/lib/libpython3.8.so.1.0
// #48 0x00007fcf7e56d21e in _PyObject_FastCallDict () from /usr/lib/libpython3.8.so.1.0
// #49 0x00007fcf7e63b0ed in ?? () from /usr/lib/libpython3.8.so.1.0
// #50 0x00007fcf7e56db84 in _PyObject_MakeTpCall () from /usr/lib/libpython3.8.so.1.0
// #51 0x00007fcf7e568f54 in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #52 0x00007fcf7e575138 in _PyFunction_Vectorcall () from /usr/lib/libpython3.8.so.1.0
// #53 0x00007fcf7e564ac1 in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #54 0x00007fcf7e563762 in _PyEval_EvalCodeWithName () from /usr/lib/libpython3.8.so.1.0
// #55 0x00007fcf7e5751cd in _PyFunction_Vectorcall () from /usr/lib/libpython3.8.so.1.0
// #56 0x00007fcf7e60886a in ?? () from /usr/lib/libpython3.8.so.1.0
// #57 0x00007fcf7e5289c5 in ?? () from /usr/lib/libpython3.8.so.1.0
// #58 0x00007fcf7e56c63d in ?? () from /usr/lib/libpython3.8.so.1.0
// #59 0x00007fcf7e584f8f in PyVectorcall_Call () from /usr/lib/libpython3.8.so.1.0
// #60 0x00007fcf7e56a355 in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #61 0x00007fcf7e575138 in _PyFunction_Vectorcall () from /usr/lib/libpython3.8.so.1.0
// #62 0x00007fcf7e564ac1 in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #63 0x00007fcf7e575138 in _PyFunction_Vectorcall () from /usr/lib/libpython3.8.so.1.0
// #64 0x00007fcf7e564ac1 in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #65 0x00007fcf7e575138 in _PyFunction_Vectorcall () from /usr/lib/libpython3.8.so.1.0
// #66 0x00007fcf7e564ac1 in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #67 0x00007fcf7e575138 in _PyFunction_Vectorcall () from /usr/lib/libpython3.8.so.1.0
// #68 0x00007fcf7e564ac1 in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #69 0x00007fcf7e575138 in _PyFunction_Vectorcall () from /usr/lib/libpython3.8.so.1.0
// #70 0x00007fcf7e564ac1 in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #71 0x00007fcf7e563044 in _PyEval_EvalCodeWithName () from /usr/lib/libpython3.8.so.1.0
// #72 0x00007fcf7e584952 in ?? () from /usr/lib/libpython3.8.so.1.0
// #73 0x00007fcf7e5654d9 in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #74 0x00007fcf7e575138 in _PyFunction_Vectorcall () from /usr/lib/libpython3.8.so.1.0
// #75 0x00007fcf7e5646fd in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #76 0x00007fcf7e563044 in _PyEval_EvalCodeWithName () from /usr/lib/libpython3.8.so.1.0
// #77 0x00007fcf7e6143a3 in PyEval_EvalCode () from /usr/lib/libpython3.8.so.1.0
// #78 0x00007fcf7e6197bd in ?? () from /usr/lib/libpython3.8.so.1.0
// #79 0x00007fcf7e5759d8 in ?? () from /usr/lib/libpython3.8.so.1.0
// #80 0x00007fcf7e5646fd in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #81 0x00007fcf7e563044 in _PyEval_EvalCodeWithName () from /usr/lib/libpython3.8.so.1.0
// #82 0x00007fcf7e5751cd in _PyFunction_Vectorcall () from /usr/lib/libpython3.8.so.1.0
// #83 0x00007fcf7e5646fd in _PyEval_EvalFrameDefault () from /usr/lib/libpython3.8.so.1.0
// #84 0x00007fcf7e563044 in _PyEval_EvalCodeWithName () from /usr/lib/libpython3.8.so.1.0
// #85 0x00007fcf7e5751cd in _PyFunction_Vectorcall () from /usr/lib/libpython3.8.so.1.0
// #86 0x00007fcf7e5882c2 in PyObject_Call () from /usr/lib/libpython3.8.so.1.0
// #87 0x00007fcf7e633811 in ?? () from /usr/lib/libpython3.8.so.1.0
// #88 0x00007fcf7e62c6df in Py_RunMain () from /usr/lib/libpython3.8.so.1.0
// #89 0x00007fcf7e608c59 in Py_BytesMain () from /usr/lib/libpython3.8.so.1.0
// #90 0x00007fcf7e2a5152 in __libc_start_main () from /usr/lib/libc.so.6
// #91 0x000055c13ded504e in _start ()
// Error in <HandleInterpreterException>: Trying to access a pointer that points to an invalid memory address..
// Execution of your code was aborted.
// input_line_72:9:3: warning: invalid memory pointer passed to a callee:
//   canvas->SetLogy();
//   ^~~~~~
